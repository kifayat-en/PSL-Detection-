# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
import numpy as np
import math
import time
import os

cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=1)

offset = 20
imgSize = 300
folder = "Data/Hay ہ"
os.makedirs(folder, exist_ok=True)
counter = 0

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read from webcam.")
        break

    hands, img = detector.findHands(img)

    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']

        # Ensure cropping box is within image bounds
        y1 = max(0, y - offset)
        y2 = min(img.shape[0], y + h + offset)
        x1 = max(0, x - offset)
        x2 = min(img.shape[1], x + w + offset)

        imgCrop = img[y1:y2, x1:x2]

        if imgCrop.size == 0:
            print("Warning: Empty crop, skipping frame.")
            continue

        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
        aspectRatio = h / w

        try:
            if aspectRatio > 1:
                k = imgSize / h
                wCal = math.ceil(k * w)
                imgResize = cv2.resize(imgCrop, (wCal, imgSize))
                wGap = math.ceil((imgSize - wCal) / 2)
                imgWhite[:, wGap:wCal + wGap] = imgResize
            else:
                k = imgSize / w
                hCal = math.ceil(k * h)
                imgResize = cv2.resize(imgCrop, (imgSize, hCal))
                hGap = math.ceil((imgSize - hCal) / 2)
                imgWhite[hGap:hCal + hGap, :] = imgResize

            cv2.imshow("ImageCrop", imgCrop)
            cv2.imshow("ImageWhite", imgWhite)

        except Exception as e:
            print("Resize error:", e)
            continue

    cv2.imshow("Image", img)
    key = cv2.waitKey(1)

    if key == ord("s") and hands:
        counter += 1
        filename = f'{folder}/Image_{time.time()}.jpg'
        cv2.imwrite(filename, imgWhite)
        print(f"Saved {filename} | Count: {counter}")
# Out:
# 2025-08-18 14:32:15.727522: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755509543.635666  968681 gl_context.cc:357] GL version: 2.1 (2.1 ATI-4.14.1), renderer: AMD Radeon Pro 560 OpenGL Engine
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1755509543.653383  969022 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1755509543.672790  969022 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Users/apple/anaconda3/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Saved Data/Hay ہ/Image_1755509571.524724.jpg | Count: 1
# Saved Data/Hay ہ/Image_1755509571.992219.jpg | Count: 2
# Saved Data/Hay ہ/Image_1755509572.123393.jpg | Count: 3
# Saved Data/Hay ہ/Image_1755509572.166446.jpg | Count: 4
# Saved Data/Hay ہ/Image_1755509572.303564.jpg | Count: 5
# Saved Data/Hay ہ/Image_1755509572.370704.jpg | Count: 6
# Saved Data/Hay ہ/Image_1755509572.442623.jpg | Count: 7
# Saved Data/Hay ہ/Image_1755509572.506859.jpg | Count: 8
# Saved Data/Hay ہ/Image_1755509572.581731.jpg | Count: 9
# Saved Data/Hay ہ/Image_1755509572.713802.jpg | Count: 10
# Saved Data/Hay ہ/Image_1755509572.79175.jpg | Count: 11
# Saved Data/Hay ہ/Image_1755509572.8535192.jpg | Count: 12
# Saved Data/Hay ہ/Image_1755509572.917008.jpg | Count: 13
# Saved Data/Hay ہ/Image_1755509573.0243368.jpg | Count: 14
# Saved Data/Hay ہ/Image_1755509573.09087.jpg | Count: 15
# Saved Data/Hay ہ/Image_1755509573.1669161.jpg | Count: 16
# Saved Data/Hay ہ/Image_1755509573.299521.jpg | Count: 17
# Saved Data/Hay ہ/Image_1755509573.368321.jpg | Count: 18
# Saved Data/Hay ہ/Image_1755509573.448332.jpg | Count: 19
# Saved Data/Hay ہ/Image_1755509573.507272.jpg | Count: 20
# Saved Data/Hay ہ/Image_1755509573.576811.jpg | Count: 21
# Saved Data/Hay ہ/Image_1755509573.712885.jpg | Count: 22
# Saved Data/Hay ہ/Image_1755509573.781099.jpg | Count: 23
# Saved Data/Hay ہ/Image_1755509573.853738.jpg | Count: 24
# Saved Data/Hay ہ/Image_1755509573.918605.jpg | Count: 25
# Saved Data/Hay ہ/Image_1755509574.067018.jpg | Count: 26
# Saved Data/Hay ہ/Image_1755509574.127771.jpg | Count: 27
# Saved Data/Hay ہ/Image_1755509574.1967092.jpg | Count: 28
# Saved Data/Hay ہ/Image_1755509574.267297.jpg | Count: 29
# Saved Data/Hay ہ/Image_1755509574.364948.jpg | Count: 30
# Saved Data/Hay ہ/Image_1755509574.4731011.jpg | Count: 31
# Saved Data/Hay ہ/Image_1755509574.540545.jpg | Count: 32
# Saved Data/Hay ہ/Image_1755509574.614045.jpg | Count: 33
# Saved Data/Hay ہ/Image_1755509574.674834.jpg | Count: 34
# Saved Data/Hay ہ/Image_1755509574.743819.jpg | Count: 35
# Saved Data/Hay ہ/Image_1755509574.882304.jpg | Count: 36
# Saved Data/Hay ہ/Image_1755509574.952329.jpg | Count: 37
# Saved Data/Hay ہ/Image_1755509575.0236769.jpg | Count: 38
# Saved Data/Hay ہ/Image_1755509575.0902789.jpg | Count: 39
# Saved Data/Hay ہ/Image_1755509575.161102.jpg | Count: 40
# Saved Data/Hay ہ/Image_1755509575.293329.jpg | Count: 41
# Saved Data/Hay ہ/Image_1755509575.336951.jpg | Count: 42
# Saved Data/Hay ہ/Image_1755509575.474401.jpg | Count: 43
# Saved Data/Hay ہ/Image_1755509575.543304.jpg | Count: 44
# Saved Data/Hay ہ/Image_1755509575.608752.jpg | Count: 45
# Saved Data/Hay ہ/Image_1755509575.673878.jpg | Count: 46
# Saved Data/Hay ہ/Image_1755509575.74468.jpg | Count: 47
# Saved Data/Hay ہ/Image_1755509575.8811939.jpg | Count: 48
# Saved Data/Hay ہ/Image_1755509575.951095.jpg | Count: 49
# Saved Data/Hay ہ/Image_1755509576.020565.jpg | Count: 50
# Saved Data/Hay ہ/Image_1755509576.0920691.jpg | Count: 51
# Saved Data/Hay ہ/Image_1755509576.161345.jpg | Count: 52
# Saved Data/Hay ہ/Image_1755509576.298271.jpg | Count: 53
# Saved Data/Hay ہ/Image_1755509576.366279.jpg | Count: 54
# Saved Data/Hay ہ/Image_1755509576.444483.jpg | Count: 55
# Saved Data/Hay ہ/Image_1755509576.502283.jpg | Count: 56
# Saved Data/Hay ہ/Image_1755509576.641469.jpg | Count: 57
# Saved Data/Hay ہ/Image_1755509576.707415.jpg | Count: 58
# Saved Data/Hay ہ/Image_1755509576.7772648.jpg | Count: 59
# Saved Data/Hay ہ/Image_1755509576.848164.jpg | Count: 60
# Saved Data/Hay ہ/Image_1755509576.915891.jpg | Count: 61
# Saved Data/Hay ہ/Image_1755509577.0543091.jpg | Count: 62
# Saved Data/Hay ہ/Image_1755509577.1212711.jpg | Count: 63
# Saved Data/Hay ہ/Image_1755509577.192936.jpg | Count: 64
# Saved Data/Hay ہ/Image_1755509577.262231.jpg | Count: 65
# Saved Data/Hay ہ/Image_1755509577.330007.jpg | Count: 66
# Saved Data/Hay ہ/Image_1755509577.4693198.jpg | Count: 67
# Saved Data/Hay ہ/Image_1755509577.530865.jpg | Count: 68
# Saved Data/Hay ہ/Image_1755509577.644525.jpg | Count: 69
# Saved Data/Hay ہ/Image_1755509577.702268.jpg | Count: 70
# Saved Data/Hay ہ/Image_1755509577.814847.jpg | Count: 71
# Saved Data/Hay ہ/Image_1755509577.88417.jpg | Count: 72
# Saved Data/Hay ہ/Image_1755509577.947584.jpg | Count: 73
# Saved Data/Hay ہ/Image_1755509578.0193532.jpg | Count: 74
# Saved Data/Hay ہ/Image_1755509578.0864441.jpg | Count: 75
# Saved Data/Hay ہ/Image_1755509578.226503.jpg | Count: 76
# Saved Data/Hay ہ/Image_1755509578.294303.jpg | Count: 77
# Saved Data/Hay ہ/Image_1755509578.364773.jpg | Count: 78
# Saved Data/Hay ہ/Image_1755509578.4425359.jpg | Count: 79
# Saved Data/Hay ہ/Image_1755509578.499817.jpg | Count: 80
# Saved Data/Hay ہ/Image_1755509578.640554.jpg | Count: 81
# Saved Data/Hay ہ/Image_1755509578.7070458.jpg | Count: 82
# Saved Data/Hay ہ/Image_1755509578.7779882.jpg | Count: 83
# Saved Data/Hay ہ/Image_1755509578.850817.jpg | Count: 84
# Saved Data/Hay ہ/Image_1755509578.92021.jpg | Count: 85
# Saved Data/Hay ہ/Image_1755509579.053807.jpg | Count: 86
# Saved Data/Hay ہ/Image_1755509579.123441.jpg | Count: 87
# Saved Data/Hay ہ/Image_1755509579.194786.jpg | Count: 88
# Saved Data/Hay ہ/Image_1755509579.261895.jpg | Count: 89
# Saved Data/Hay ہ/Image_1755509579.3312361.jpg | Count: 90
# Saved Data/Hay ہ/Image_1755509579.5575979.jpg | Count: 91
# Saved Data/Hay ہ/Image_1755509579.607826.jpg | Count: 92
# Saved Data/Hay ہ/Image_1755509579.6940942.jpg | Count: 93
# Saved Data/Hay ہ/Image_1755509579.751916.jpg | Count: 94
# Saved Data/Hay ہ/Image_1755509579.814781.jpg | Count: 95
# Saved Data/Hay ہ/Image_1755509579.881477.jpg | Count: 96
# Saved Data/Hay ہ/Image_1755509579.953852.jpg | Count: 97
# Saved Data/Hay ہ/Image_1755509580.0233018.jpg | Count: 98
# Saved Data/Hay ہ/Image_1755509580.092881.jpg | Count: 99
# Saved Data/Hay ہ/Image_1755509580.2331579.jpg | Count: 100
# Saved Data/Hay ہ/Image_1755509580.29097.jpg | Count: 101
# Saved Data/Hay ہ/Image_1755509580.39775.jpg | Count: 102
# Saved Data/Hay ہ/Image_1755509580.442998.jpg | Count: 103
# Saved Data/Hay ہ/Image_1755509580.501431.jpg | Count: 104
# Saved Data/Hay ہ/Image_1755509598.207102.jpg | Count: 105
# Saved Data/Hay ہ/Image_1755509598.6898592.jpg | Count: 106
# Saved Data/Hay ہ/Image_1755509598.759371.jpg | Count: 107
# Saved Data/Hay ہ/Image_1755509598.828087.jpg | Count: 108
# Saved Data/Hay ہ/Image_1755509598.965475.jpg | Count: 109
# Saved Data/Hay ہ/Image_1755509599.030418.jpg | Count: 110
# Saved Data/Hay ہ/Image_1755509599.1406631.jpg | Count: 111
# Saved Data/Hay ہ/Image_1755509599.211523.jpg | Count: 112
# Saved Data/Hay ہ/Image_1755509599.275754.jpg | Count: 113
# Saved Data/Hay ہ/Image_1755509599.346205.jpg | Count: 114
# Saved Data/Hay ہ/Image_1755509599.417102.jpg | Count: 115
# Saved Data/Hay ہ/Image_1755509599.5502021.jpg | Count: 116
# Saved Data/Hay ہ/Image_1755509599.620787.jpg | Count: 117
# Saved Data/Hay ہ/Image_1755509599.689554.jpg | Count: 118
# Saved Data/Hay ہ/Image_1755509599.757476.jpg | Count: 119
# Saved Data/Hay ہ/Image_1755509599.828067.jpg | Count: 120
# Saved Data/Hay ہ/Image_1755509599.9642692.jpg | Count: 121
# Saved Data/Hay ہ/Image_1755509600.034509.jpg | Count: 122
# Saved Data/Hay ہ/Image_1755509600.100739.jpg | Count: 123
# Saved Data/Hay ہ/Image_1755509600.169782.jpg | Count: 124
# Saved Data/Hay ہ/Image_1755509604.650329.jpg | Count: 125
# Saved Data/Hay ہ/Image_1755509605.2034922.jpg | Count: 126
# Saved Data/Hay ہ/Image_1755509605.2703612.jpg | Count: 127
# Saved Data/Hay ہ/Image_1755509605.340555.jpg | Count: 128
# Saved Data/Hay ہ/Image_1755509605.414083.jpg | Count: 129
# Saved Data/Hay ہ/Image_1755509605.543933.jpg | Count: 130
# Saved Data/Hay ہ/Image_1755509605.613727.jpg | Count: 131
# Saved Data/Hay ہ/Image_1755509605.6859279.jpg | Count: 132
# Saved Data/Hay ہ/Image_1755509605.75363.jpg | Count: 133
# Saved Data/Hay ہ/Image_1755509605.824427.jpg | Count: 134
# Saved Data/Hay ہ/Image_1755509605.9630752.jpg | Count: 135
# Saved Data/Hay ہ/Image_1755509606.0308568.jpg | Count: 136
# Saved Data/Hay ہ/Image_1755509606.0976279.jpg | Count: 137
# Saved Data/Hay ہ/Image_1755509606.1668139.jpg | Count: 138
# Saved Data/Hay ہ/Image_1755509606.236139.jpg | Count: 139
# Saved Data/Hay ہ/Image_1755509606.373897.jpg | Count: 140
# Saved Data/Hay ہ/Image_1755509606.413703.jpg | Count: 141
# Saved Data/Hay ہ/Image_1755509609.542283.jpg | Count: 142
# Saved Data/Hay ہ/Image_1755509610.027118.jpg | Count: 143
# Saved Data/Hay ہ/Image_1755509615.950589.jpg | Count: 144
# Saved Data/Hay ہ/Image_1755509616.435901.jpg | Count: 145
# Saved Data/Hay ہ/Image_1755509616.9175282.jpg | Count: 146
# Saved Data/Hay ہ/Image_1755509617.1239738.jpg | Count: 147
# Saved Data/Hay ہ/Image_1755509617.330859.jpg | Count: 148
# Saved Data/Hay ہ/Image_1755509617.880547.jpg | Count: 149
# Saved Data/Hay ہ/Image_1755509618.227757.jpg | Count: 150
